# %%
import pickle
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import torch
from neuralhydrology.evaluation import metrics
from neuralhydrology.nh_run import start_run, eval_run
import matplotlib.dates as mdates
import os
import numpy as np
area = 111639970.52


run_dir1 = Path('runs/CARAVAN_Basins_2503_115152')
base_dir1 = Path('runs/CARAVAN_Basins_2503_115152/test')
for i in range(1, 21):
    eval_run(epoch = i,run_dir=run_dir1, period="test")

run_dir2 = Path('runs/CARAVAN_Basins_2603_145637')
base_dir2 = Path('runs/CARAVAN_Basins_2603_145637/test')
for i in range(1, 21):
    eval_run(epoch = i,run_dir=run_dir2, period="test")

run_dir3 = Path('runs/CARAVAN_Basins_0205_154853')
base_dir3 = Path('runs/CARAVAN_Basins_0205_154853/test')
for i in range(1, 21):
    eval_run(epoch = i,run_dir=run_dir3, period="test")
# Out:
# d:\Users\ddknop\Documents\envs\neuralhydrology\lib\site-packages\neuralhydrology\evaluation\tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Evaluation:   0%|          | 0/1 [00:00<?, ?it/s]basins?: None
# subdataset: None
# subdatasetdirs: [WindowsPath('output_caravan_US/attributes/10023000'), WindowsPath('output_caravan_US/attributes/10166430'), WindowsPath('output_caravan_US/attributes/10172700'), WindowsPath('output_caravan_US/attributes/10172800'), WindowsPath('output_caravan_US/attributes/10173450'), WindowsPath('output_caravan_US/attributes/10205030'), WindowsPath('output_caravan_US/attributes/10234500'), WindowsPath('output_caravan_US/attributes/10242000'), WindowsPath('output_caravan_US/attributes/10244950'), WindowsPath('output_caravan_US/attributes/10249300'), WindowsPath('output_caravan_US/attributes/10258000'), WindowsPath('output_caravan_US/attributes/10258500'), WindowsPath('output_caravan_US/attributes/10259000'), WindowsPath('output_caravan_US/attributes/10259200'), WindowsPath('output_caravan_US/attributes/10263500'), WindowsPath('output_caravan_US/attributes/10310500'), WindowsPath('output_caravan_US/attributes/10316500'), WindowsPath('output_caravan_US/attributes/10329500'), WindowsPath('output_caravan_US/attributes/10336645'), WindowsPath('output_caravan_US/attributes/10336660'), WindowsPath('output_caravan_US/attributes/10336740'), WindowsPath('output_caravan_US/attributes/10343500'), WindowsPath('output_caravan_US/attributes/10348850'), WindowsPath('output_caravan_US/attributes/10396000'), WindowsPath('output_caravan_US/attributes/11098000'), WindowsPath('output_caravan_US/attributes/11124500'), WindowsPath('output_caravan_US/attributes/11141280'), WindowsPath('output_caravan_US/attributes/11143000'), WindowsPath('output_caravan_US/attributes/11148900'), WindowsPath('output_caravan_US/attributes/11151300'), WindowsPath('output_caravan_US/attributes/11162500'), WindowsPath('output_caravan_US/attributes/11176400'), WindowsPath('output_caravan_US/attributes/11180500'), WindowsPath('output_caravan_US/attributes/11180960'), WindowsPath('output_caravan_US/attributes/11224500'), WindowsPath('output_caravan_US/attributes/11230500'), WindowsPath('output_caravan_US/attributes/11237500'), WindowsPath('output_caravan_US/attributes/11253310'), WindowsPath('output_caravan_US/attributes/11264500'), WindowsPath('output_caravan_US/attributes/11266500'), WindowsPath('output_caravan_US/attributes/11274500'), WindowsPath('output_caravan_US/attributes/11274630'), WindowsPath('output_caravan_US/attributes/11284400'), WindowsPath('output_caravan_US/attributes/11299600'), WindowsPath('output_caravan_US/attributes/11381500'), WindowsPath('output_caravan_US/attributes/11383500'), WindowsPath('output_caravan_US/attributes/11451100'), WindowsPath('output_caravan_US/attributes/11468500'), WindowsPath('output_caravan_US/attributes/11473900'), WindowsPath('output_caravan_US/attributes/11475560'), WindowsPath('output_caravan_US/attributes/11476600'), WindowsPath('output_caravan_US/attributes/11478500'), WindowsPath('output_caravan_US/attributes/11480390'), WindowsPath('output_caravan_US/attributes/11481200'), WindowsPath('output_caravan_US/attributes/11482500'), WindowsPath('output_caravan_US/attributes/11522500'), WindowsPath('output_caravan_US/attributes/11523200'), WindowsPath('output_caravan_US/attributes/11528700'), WindowsPath('output_caravan_US/attributes/11532500'), WindowsPath('output_caravan_US/attributes/12010000'), WindowsPath('output_caravan_US/attributes/12013500'), WindowsPath('output_caravan_US/attributes/12020000'), WindowsPath('output_caravan_US/attributes/12025000'), WindowsPath('output_caravan_US/attributes/12025700'), WindowsPath('output_caravan_US/attributes/12035000'), WindowsPath('output_caravan_US/attributes/12040500'), WindowsPath('output_caravan_US/attributes/12041200'), WindowsPath('output_caravan_US/attributes/12043000'), WindowsPath('output_caravan_US/attributes/12048000'), WindowsPath('output_caravan_US/attributes/12054000'), WindowsPath('output_caravan_US/attributes/12056500'), WindowsPath('output_caravan_US/attributes/12073500'), WindowsPath('output_caravan_US/attributes/12082500'), WindowsPath('output_caravan_US/attributes ...
# basinstest: ['6']
# names: ['6']
# dfs: [            p_mean  pet_mean_ERA5_LAND  pet_mean_FAO_PM  aridity_ERA5_LAND  \
# gauge_id
# 6         2.208724            3.663488         1.576936           1.658644
#
#           aridity_FAO_PM  frac_snow  moisture_index_ERA5_LAND  \
# gauge_id
# 6               0.713958          0                 -0.224735
#
#           seasonality_ERA5_LAND  moisture_index_FAO_PM  seasonality_FAO_PM  \
# gauge_id
# 6                      1.168391               0.307145            1.168536
#
#           ...  ria_ha_usu  riv_tc_usu  pop_ct_usu  dor_pc_pva  \
# gauge_id  ...
# 6         ...    1192.807     9015.12    2078.817           0
#
#           area_fraction_used_for_aggregation  gauge_lat  gauge_lon  \
# gauge_id
# 6                                          1  50.885418    3.68613
#
#                     gauge_name  country        area
# gauge_id
# 6         Nederzwalm/Zwalmbeek  Belgium  111.249644
#
# [1 rows x 215 columns]]
# dfprint: <bound method NDFrame.head of             p_mean  pet_mean_ERA5_LAND  pet_mean_FAO_PM  aridity_ERA5_LAND  \
# gauge_id
# 6         2.208724            3.663488         1.576936           1.658644
#
#           aridity_FAO_PM  frac_snow  moisture_index_ERA5_LAND  \
# gauge_id
# 6               0.713958          0                 -0.224735
#
#           seasonality_ERA5_LAND  moisture_index_FAO_PM  seasonality_FAO_PM  \
# gauge_id
# 6                      1.168391               0.307145            1.168536
#
#           ...  ria_ha_usu  riv_tc_usu  pop_ct_usu  dor_pc_pva  \
# gauge_id  ...
# 6         ...    1192.807     9015.12    2078.817           0
#
#           area_fraction_used_for_aggregation  gauge_lat  gauge_lon  \
# gauge_id
# 6                                          1  50.885418    3.68613
#
#                     gauge_name  country        area
# gauge_id
# 6         Nederzwalm/Zwalmbeek  Belgium  111.249644
#
# [1 rows x 215 columns]>
# dfindexen: Index(['6'], dtype='object')
# df      p_mean  pet_mean_ERA5_LAND  pet_mean_FAO_PM  aridity_ERA5_LAND  \
# 6  2.208724            3.663488         1.576936           1.658644
#
#    aridity_FAO_PM  frac_snow  moisture_index_ERA5_LAND  seasonality_ERA5_LAND  \
# 6        0.713958          0                 -0.224735               1.168391
#
#    moisture_index_FAO_PM  seasonality_FAO_PM  ...  ria_ha_usu  riv_tc_usu  \
# 6               0.307145            1.168536  ...    1192.807     9015.12
#
#    pop_ct_usu  dor_pc_pva  area_fraction_used_for_aggregation  gauge_lat  \
# 6    2078.817           0                                   1  50.885418
#
#    gauge_lon            gauge_name  country        area
# 6    3.68613  Nederzwalm/Zwalmbeek  Belgium  111.249644
#
# [1 rows x 215 columns]
# # Evaluation: 100%|██████████| 1/1 [00:01<00:00,  1.30s/it]
# d:\Users\ddknop\Documents\envs\neuralhydrology\lib\site-packages\neuralhydrology\evaluation\tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Evaluation:   0%|          | 0/1 [00:00<?, ?it/s]basins?: None
# subdataset: None
# subdatasetdirs: [WindowsPath('output_caravan_US/attributes/10023000'), WindowsPath('output_caravan_US/attributes/10166430'), WindowsPath('output_caravan_US/attributes/10172700'), WindowsPath('output_caravan_US/attributes/10172800'), WindowsPath('output_caravan_US/attributes/10173450'), WindowsPath('output_caravan_US/attributes/10205030'), WindowsPath('output_caravan_US/attributes/10234500'), WindowsPath('output_caravan_US/attributes/10242000'), WindowsPath('output_caravan_US/attributes/10244950'), WindowsPath('output_caravan_US/attributes/10249300'), WindowsPath('output_caravan_US/attributes/10258000'), WindowsPath('output_caravan_US/attributes/10258500'), WindowsPath('output_caravan_US/attributes/10259000'), WindowsPath('output_caravan_US/attributes/10259200'), WindowsPath('output_caravan_US/attributes/10263500'), WindowsPath('output_caravan_US/attributes/10310500'), WindowsPath('output_caravan_US/attributes/10316500'), WindowsPath('output_caravan_US/attributes/10329500'), WindowsPath('output_caravan_US/attributes/10336645'), WindowsPath('output_caravan_US/attributes/10336660'), WindowsPath('output_caravan_US/attributes/10336740'), WindowsPath('output_caravan_US/attributes/10343500'), WindowsPath('output_caravan_US/attributes/10348850'), WindowsPath('output_caravan_US/attributes/10396000'), WindowsPath('output_caravan_US/attributes/11098000'), WindowsPath('output_caravan_US/attributes/11124500'), WindowsPath('output_caravan_US/attributes/11141280'), WindowsPath('output_caravan_US/attributes/11143000'), WindowsPath('output_caravan_US/attributes/11148900'), WindowsPath('output_caravan_US/attributes/11151300'), WindowsPath('output_caravan_US/attributes/11162500'), WindowsPath('output_caravan_US/attributes/11176400'), WindowsPath('output_caravan_US/attributes/11180500'), WindowsPath('output_caravan_US/attributes/11180960'), WindowsPath('output_caravan_US/attributes/11224500'), WindowsPath('output_caravan_US/attributes/11230500'), WindowsPath('output_caravan_US/attributes/11237500'), WindowsPath('output_caravan_US/attributes/11253310'), WindowsPath('output_caravan_US/attributes/11264500'), WindowsPath('output_caravan_US/attributes/11266500'), WindowsPath('output_caravan_US/attributes/11274500'), WindowsPath('output_caravan_US/attributes/11274630'), WindowsPath('output_caravan_US/attributes/11284400'), WindowsPath('output_caravan_US/attributes/11299600'), WindowsPath('output_caravan_US/attributes/11381500'), WindowsPath('output_caravan_US/attributes/11383500'), WindowsPath('output_caravan_US/attributes/11451100'), WindowsPath('output_caravan_US/attributes/11468500'), WindowsPath('output_caravan_US/attributes/11473900'), WindowsPath('output_caravan_US/attributes/11475560'), WindowsPath('output_caravan_US/attributes/11476600'), WindowsPath('output_caravan_US/attributes/11478500'), WindowsPath('output_caravan_US/attributes/11480390'), WindowsPath('output_caravan_US/attributes/11481200'), WindowsPath('output_caravan_US/attributes/11482500'), WindowsPath('output_caravan_US/attributes/11522500'), WindowsPath('output_caravan_US/attributes/11523200'), WindowsPath('output_caravan_US/attributes/11528700'), WindowsPath('output_caravan_US/attributes/11532500'), WindowsPath('output_caravan_US/attributes/12010000'), WindowsPath('output_caravan_US/attributes/12013500'), WindowsPath('output_caravan_US/attributes/12020000'), WindowsPath('output_caravan_US/attributes/12025000'), WindowsPath('output_caravan_US/attributes/12025700'), WindowsPath('output_caravan_US/attributes/12035000'), WindowsPath('output_caravan_US/attributes/12040500'), WindowsPath('output_caravan_US/attributes/12041200'), WindowsPath('output_caravan_US/attributes/12043000'), WindowsPath('output_caravan_US/attributes/12048000'), WindowsPath('output_caravan_US/attributes/12054000'), WindowsPath('output_caravan_US/attributes/12056500'), WindowsPath('output_caravan_US/attributes/12073500'), WindowsPath('output_caravan_US/attributes/12082500'), WindowsPath('output_caravan_US/attributes ...
# basinstest: ['6']
# names: ['6']
# dfs: [            p_mean  pet_mean_ERA5_LAND  pet_mean_FAO_PM  aridity_ERA5_LAND  \
# gauge_id
# 6         2.208724            3.663488         1.576936           1.658644
#
#           aridity_FAO_PM  frac_snow  moisture_index_ERA5_LAND  \
# gauge_id
# 6               0.713958          0                 -0.224735
#
#           seasonality_ERA5_LAND  moisture_index_FAO_PM  seasonality_FAO_PM  \
# gauge_id
# 6                      1.168391               0.307145            1.168536
#
#           ...  ria_ha_usu  riv_tc_usu  pop_ct_usu  dor_pc_pva  \
# gauge_id  ...
# 6         ...    1192.807     9015.12    2078.817           0
#
#           area_fraction_used_for_aggregation  gauge_lat  gauge_lon  \
# gauge_id
# 6                                          1  50.885418    3.68613
#
#                     gauge_name  country        area
# gauge_id
# 6         Nederzwalm/Zwalmbeek  Belgium  111.249644
#
# [1 rows x 215 columns]]
# dfprint: <bound method NDFrame.head of             p_mean  pet_mean_ERA5_LAND  pet_mean_FAO_PM  aridity_ERA5_LAND  \
# gauge_id
# 6         2.208724            3.663488         1.576936           1.658644
#
#           aridity_FAO_PM  frac_snow  moisture_index_ERA5_LAND  \
# gauge_id
# 6               0.713958          0                 -0.224735
#
#           seasonality_ERA5_LAND  moisture_index_FAO_PM  seasonality_FAO_PM  \
# gauge_id
# 6                      1.168391               0.307145            1.168536
#
#           ...  ria_ha_usu  riv_tc_usu  pop_ct_usu  dor_pc_pva  \
# gauge_id  ...
# 6         ...    1192.807     9015.12    2078.817           0
#
#           area_fraction_used_for_aggregation  gauge_lat  gauge_lon  \
# gauge_id
# 6                                          1  50.885418    3.68613
#
#                     gauge_name  country        area
# gauge_id
# 6         Nederzwalm/Zwalmbeek  Belgium  111.249644
#
# [1 rows x 215 columns]>
# dfindexen: Index(['6'], dtype='object')
# df      p_mean  pet_mean_ERA5_LAND  pet_mean_FAO_PM  aridity_ERA5_LAND  \
# 6  2.208724            3.663488         1.576936           1.658644
#
#    aridity_FAO_PM  frac_snow  moisture_index_ERA5_LAND  seasonality_ERA5_LAND  \
# 6        0.713958          0                 -0.224735               1.168391
#
#    moisture_index_FAO_PM  seasonality_FAO_PM  ...  ria_ha_usu  riv_tc_usu  \
# 6               0.307145            1.168536  ...    1192.807     9015.12
#
#    pop_ct_usu  dor_pc_pva  area_fraction_used_for_aggregation  gauge_lat  \
# 6    2078.817           0                                   1  50.885418
#
#    gauge_lon            gauge_name  country        area
# 6    3.68613  Nederzwalm/Zwalmbeek  Belgium  111.249644
#
# [1 rows x 215 columns]
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  2.08it/s]
# d:\Users\ddknop\Documents\envs\neuralhydrology\lib\site-packages\neuralhydrology\evaluation\tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Evaluation:   0%|          | 0/1 [00:00<?, ?it/s]basins?: None
# subdataset: None
# subdatasetdirs: [WindowsPath('output_caravan_US/attributes/10023000'), WindowsPath('output_caravan_US/attributes/10166430'), WindowsPath('output_caravan_US/attributes/10172700'), WindowsPath('output_caravan_US/attributes/10172800'), WindowsPath('output_caravan_US/attributes/10173450'), WindowsPath('output_caravan_US/attributes/10205030'), WindowsPath('output_caravan_US/attributes/10234500'), WindowsPath('output_caravan_US/attributes/10242000'), WindowsPath('output_caravan_US/attributes/10244950'), WindowsPath('output_caravan_US/attributes/10249300'), WindowsPath('output_caravan_US/attributes/10258000'), WindowsPath('output_caravan_US/attributes/10258500'), WindowsPath('output_caravan_US/attributes/10259000'), WindowsPath('output_caravan_US/attributes/10259200'), WindowsPath('output_caravan_US/attributes/10263500'), WindowsPath('output_caravan_US/attributes/10310500'), WindowsPath('output_caravan_US/attributes/10316500'), WindowsPath('output_caravan_US/attributes/10329500'), WindowsPath('output_caravan_US/attributes/10336645'), WindowsPath('output_caravan_US/attributes/10336660'), WindowsPath('output_caravan_US/attributes/10336740'), WindowsPath('output_caravan_US/attributes/10343500'), WindowsPath('output_caravan_US/attributes/10348850'), WindowsPath('output_caravan_US/attributes/10396000'), WindowsPath('output_caravan_US/attributes/11098000'), WindowsPath('output_caravan_US/attributes/11124500'), WindowsPath('output_caravan_US/attributes/11141280'), WindowsPath('output_caravan_US/attributes/11143000'), WindowsPath('output_caravan_US/attributes/11148900'), WindowsPath('output_caravan_US/attributes/11151300'), WindowsPath('output_caravan_US/attributes/11162500'), WindowsPath('output_caravan_US/attributes/11176400'), WindowsPath('output_caravan_US/attributes/11180500'), WindowsPath('output_caravan_US/attributes/11180960'), WindowsPath('output_caravan_US/attributes/11224500'), WindowsPath('output_caravan_US/attributes/11230500'), WindowsPath('output_caravan_US/attributes/11237500'), WindowsPath('output_caravan_US/attributes/11253310'), WindowsPath('output_caravan_US/attributes/11264500'), WindowsPath('output_caravan_US/attributes/11266500'), WindowsPath('output_caravan_US/attributes/11274500'), WindowsPath('output_caravan_US/attributes/11274630'), WindowsPath('output_caravan_US/attributes/11284400'), WindowsPath('output_caravan_US/attributes/11299600'), WindowsPath('output_caravan_US/attributes/11381500'), WindowsPath('output_caravan_US/attributes/11383500'), WindowsPath('output_caravan_US/attributes/11451100'), WindowsPath('output_caravan_US/attributes/11468500'), WindowsPath('output_caravan_US/attributes/11473900'), WindowsPath('output_caravan_US/attributes/11475560'), WindowsPath('output_caravan_US/attributes/11476600'), WindowsPath('output_caravan_US/attributes/11478500'), WindowsPath('output_caravan_US/attributes/11480390'), WindowsPath('output_caravan_US/attributes/11481200'), WindowsPath('output_caravan_US/attributes/11482500'), WindowsPath('output_caravan_US/attributes/11522500'), WindowsPath('output_caravan_US/attributes/11523200'), WindowsPath('output_caravan_US/attributes/11528700'), WindowsPath('output_caravan_US/attributes/11532500'), WindowsPath('output_caravan_US/attributes/12010000'), WindowsPath('output_caravan_US/attributes/12013500'), WindowsPath('output_caravan_US/attributes/12020000'), WindowsPath('output_caravan_US/attributes/12025000'), WindowsPath('output_caravan_US/attributes/12025700'), WindowsPath('output_caravan_US/attributes/12035000'), WindowsPath('output_caravan_US/attributes/12040500'), WindowsPath('output_caravan_US/attributes/12041200'), WindowsPath('output_caravan_US/attributes/12043000'), WindowsPath('output_caravan_US/attributes/12048000'), WindowsPath('output_caravan_US/attributes/12054000'), WindowsPath('output_caravan_US/attributes/12056500'), WindowsPath('output_caravan_US/attributes/12073500'), WindowsPath('output_caravan_US/attributes/12082500'), WindowsPath('output_caravan_US/attributes ...
# basinstest: ['6']
# names: ['6']
# dfs: [            p_mean  pet_mean_ERA5_LAND  pet_mean_FAO_PM  aridity_ERA5_LAND  \
# gauge_id
# 6         2.208724            3.663488         1.576936           1.658644
#
#           aridity_FAO_PM  frac_snow  moisture_index_ERA5_LAND  \
# gauge_id
# 6               0.713958          0                 -0.224735
#
#           seasonality_ERA5_LAND  moisture_index_FAO_PM  seasonality_FAO_PM  \
# gauge_id
# 6                      1.168391               0.307145            1.168536
#
#           ...  ria_ha_usu  riv_tc_usu  pop_ct_usu  dor_pc_pva  \
# gauge_id  ...
# 6         ...    1192.807     9015.12    2078.817           0
#
#           area_fraction_used_for_aggregation  gauge_lat  gauge_lon  \
# gauge_id
# 6                                          1  50.885418    3.68613
#
#                     gauge_name  country        area
# gauge_id
# 6         Nederzwalm/Zwalmbeek  Belgium  111.249644
#
# [1 rows x 215 columns]]
# dfprint: <bound method NDFrame.head of             p_mean  pet_mean_ERA5_LAND  pet_mean_FAO_PM  aridity_ERA5_LAND  \
# gauge_id
# 6         2.208724            3.663488         1.576936           1.658644
#
#           aridity_FAO_PM  frac_snow  moisture_index_ERA5_LAND  \
# gauge_id
# 6               0.713958          0                 -0.224735
#
#           seasonality_ERA5_LAND  moisture_index_FAO_PM  seasonality_FAO_PM  \
# gauge_id
# 6                      1.168391               0.307145            1.168536
#
#           ...  ria_ha_usu  riv_tc_usu  pop_ct_usu  dor_pc_pva  \
# gauge_id  ...
# 6         ...    1192.807     9015.12    2078.817           0
#
#           area_fraction_used_for_aggregation  gauge_lat  gauge_lon  \
# gauge_id
# 6                                          1  50.885418    3.68613
#
#                     gauge_name  country        area
# gauge_id
# 6         Nederzwalm/Zwalmbeek  Belgium  111.249644
#
# [1 rows x 215 columns]>
# dfindexen: Index(['6'], dtype='object')
# df      p_mean  pet_mean_ERA5_LAND  pet_mean_FAO_PM  aridity_ERA5_LAND  \
# 6  2.208724            3.663488         1.576936           1.658644
#
#    aridity_FAO_PM  frac_snow  moisture_index_ERA5_LAND  seasonality_ERA5_LAND  \
# 6        0.713958          0                 -0.224735               1.168391
#
#    moisture_index_FAO_PM  seasonality_FAO_PM  ...  ria_ha_usu  riv_tc_usu  \
# 6               0.307145            1.168536  ...    1192.807     9015.12
#
#    pop_ct_usu  dor_pc_pva  area_fraction_used_for_aggregation  gauge_lat  \
# 6    2078.817           0                                   1  50.885418
#
#    gauge_lon            gauge_name  country        area
# 6    3.68613  Nederzwalm/Zwalmbeek  Belgium  111.249644
#
# [1 rows x 215 columns]
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  1.75it/s]
# d:\Users\ddknop\Documents\envs\neuralhydrology\lib\site-packages\neuralhydrology\evaluation\tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Evaluation:   0%|          | 0/1 [00:00<?, ?it/s]basins?: None
# subdataset: None
# subdatasetdirs: [WindowsPath('output_caravan_US/attributes/10023000'), WindowsPath('output_caravan_US/attributes/10166430'), WindowsPath('output_caravan_US/attributes/10172700'), WindowsPath('output_caravan_US/attributes/10172800'), WindowsPath('output_caravan_US/attributes/10173450'), WindowsPath('output_caravan_US/attributes/10205030'), WindowsPath('output_caravan_US/attributes/10234500'), WindowsPath('output_caravan_US/attributes/10242000'), WindowsPath('output_caravan_US/attributes/10244950'), WindowsPath('output_caravan_US/attributes/10249300'), WindowsPath('output_caravan_US/attributes/10258000'), WindowsPath('output_caravan_US/attributes/10258500'), WindowsPath('output_caravan_US/attributes/10259000'), WindowsPath('output_caravan_US/attributes/10259200'), WindowsPath('output_caravan_US/attributes/10263500'), WindowsPath('output_caravan_US/attributes/10310500'), WindowsPath('output_caravan_US/attributes/10316500'), WindowsPath('output_caravan_US/attributes/10329500'), WindowsPath('output_caravan_US/attributes/10336645'), WindowsPath('output_caravan_US/attributes/10336660'), WindowsPath('output_caravan_US/attributes/10336740'), WindowsPath('output_caravan_US/attributes/10343500'), WindowsPath('output_caravan_US/attributes/10348850'), WindowsPath('output_caravan_US/attributes/10396000'), WindowsPath('output_caravan_US/attributes/11098000'), WindowsPath('output_caravan_US/attributes/11124500'), WindowsPath('output_caravan_US/attributes/11141280'), WindowsPath('output_caravan_US/attributes/11143000'), WindowsPath('output_caravan_US/attributes/11148900'), WindowsPath('output_caravan_US/attributes/11151300'), WindowsPath('output_caravan_US/attributes/11162500'), WindowsPath('output_caravan_US/attributes/11176400'), WindowsPath('output_caravan_US/attributes/11180500'), WindowsPath('output_caravan_US/attributes/11180960'), WindowsPath('output_caravan_US/attributes/11224500'), WindowsPath('output_caravan_US/attributes/11230500'), WindowsPath('output_caravan_US/attributes/11237500'), WindowsPath('output_caravan_US/attributes/11253310'), WindowsPath('output_caravan_US/attributes/11264500'), WindowsPath('output_caravan_US/attributes/11266500'), WindowsPath('output_caravan_US/attributes/11274500'), WindowsPath('output_caravan_US/attributes/11274630'), WindowsPath('output_caravan_US/attributes/11284400'), WindowsPath('output_caravan_US/attributes/11299600'), WindowsPath('output_caravan_US/attributes/11381500'), WindowsPath('output_caravan_US/attributes/11383500'), WindowsPath('output_caravan_US/attributes/11451100'), WindowsPath('output_caravan_US/attributes/11468500'), WindowsPath('output_caravan_US/attributes/11473900'), WindowsPath('output_caravan_US/attributes/11475560'), WindowsPath('output_caravan_US/attributes/11476600'), WindowsPath('output_caravan_US/attributes/11478500'), WindowsPath('output_caravan_US/attributes/11480390'), WindowsPath('output_caravan_US/attributes/11481200'), WindowsPath('output_caravan_US/attributes/11482500'), WindowsPath('output_caravan_US/attributes/11522500'), WindowsPath('output_caravan_US/attributes/11523200'), WindowsPath('output_caravan_US/attributes/11528700'), WindowsPath('output_caravan_US/attributes/11532500'), WindowsPath('output_caravan_US/attributes/12010000'), WindowsPath('output_caravan_US/attributes/12013500'), WindowsPath('output_caravan_US/attributes/12020000'), WindowsPath('output_caravan_US/attributes/12025000'), WindowsPath('output_caravan_US/attributes/12025700'), WindowsPath('output_caravan_US/attributes/12035000'), WindowsPath('output_caravan_US/attributes/12040500'), WindowsPath('output_caravan_US/attributes/12041200'), WindowsPath('output_caravan_US/attributes/12043000'), WindowsPath('output_caravan_US/attributes/12048000'), WindowsPath('output_caravan_US/attributes/12054000'), WindowsPath('output_caravan_US/attributes/12056500'), WindowsPath('output_caravan_US/attributes/12073500'), WindowsPath('output_caravan_US/attributes/12082500'), WindowsPath('output_caravan_US/attributes ...
# basinstest: ['6']
# names: ['6']
# dfs: [            p_mean  pet_mean_ERA5_LAND  pet_mean_FAO_PM  aridity_ERA5_LAND  \
# gauge_id
# 6         2.208724            3.663488         1.576936           1.658644
#
#           aridity_FAO_PM  frac_snow  moisture_index_ERA5_LAND  \
# gauge_id
# 6               0.713958          0                 -0.224735
#
#           seasonality_ERA5_LAND  moisture_index_FAO_PM  seasonality_FAO_PM  \
# gauge_id
# 6                      1.168391               0.307145            1.168536
#
#           ...  ria_ha_usu  riv_tc_usu  pop_ct_usu  dor_pc_pva  \
# gauge_id  ...
# 6         ...    1192.807     9015.12    2078.817           0
#
#           area_fraction_used_for_aggregation  gauge_lat  gauge_lon  \
# gauge_id
# 6                                          1  50.885418    3.68613
#
#                     gauge_name  country        area
# gauge_id
# 6         Nederzwalm/Zwalmbeek  Belgium  111.249644
#
# [1 rows x 215 columns]]
# dfprint: <bound method NDFrame.head of             p_mean  pet_mean_ERA5_LAND  pet_mean_FAO_PM  aridity_ERA5_LAND  \
# gauge_id
# 6         2.208724            3.663488         1.576936           1.658644
#
#           aridity_FAO_PM  frac_snow  moisture_index_ERA5_LAND  \
# gauge_id
# 6               0.713958          0                 -0.224735
#
#           seasonality_ERA5_LAND  moisture_index_FAO_PM  seasonality_FAO_PM  \
# gauge_id
# 6                      1.168391               0.307145            1.168536
#
#           ...  ria_ha_usu  riv_tc_usu  pop_ct_usu  dor_pc_pva  \
# gauge_id  ...
# 6         ...    1192.807     9015.12    2078.817           0
#
#           area_fraction_used_for_aggregation  gauge_lat  gauge_lon  \
# gauge_id
# 6                                          1  50.885418    3.68613
#
#                     gauge_name  country        area
# gauge_id
# 6         Nederzwalm/Zwalmbeek  Belgium  111.249644
#
# [1 rows x 215 columns]>
# dfindexen: Index(['6'], dtype='object')
# df      p_mean  pet_mean_ERA5_LAND  pet_mean_FAO_PM  aridity_ERA5_LAND  \
# 6  2.208724            3.663488         1.576936           1.658644
#
#    aridity_FAO_PM  frac_snow  moisture_index_ERA5_LAND  seasonality_ERA5_LAND  \
# 6        0.713958          0                 -0.224735               1.168391
#
#    moisture_index_FAO_PM  seasonality_FAO_PM  ...  ria_ha_usu  riv_tc_usu  \
# 6               0.307145            1.168536  ...    1192.807     9015.12
#
#    pop_ct_usu  dor_pc_pva  area_fraction_used_for_aggregation  gauge_lat  \
# 6    2078.817           0                                   1  50.885418
#
#    gauge_lon            gauge_name  country        area
# 6    3.68613  Nederzwalm/Zwalmbeek  Belgium  111.249644
#
# [1 rows x 215 columns]
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  1.96it/s]
# d:\Users\ddknop\Documents\envs\neuralhydrology\lib\site-packages\neuralhydrology\evaluation\tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Evaluation:   0%|          | 0/1 [00:00<?, ?it/s]basins?: None
# subdataset: None
# subdatasetdirs: [WindowsPath('output_caravan_US/attributes/10023000'), WindowsPath('output_caravan_US/attributes/10166430'), WindowsPath('output_caravan_US/attributes/10172700'), WindowsPath('output_caravan_US/attributes/10172800'), WindowsPath('output_caravan_US/attributes/10173450'), WindowsPath('output_caravan_US/attributes/10205030'), WindowsPath('output_caravan_US/attributes/10234500'), WindowsPath('output_caravan_US/attributes/10242000'), WindowsPath('output_caravan_US/attributes/10244950'), WindowsPath('output_caravan_US/attributes/10249300'), WindowsPath('output_caravan_US/attributes/10258000'), WindowsPath('output_caravan_US/attributes/10258500'), WindowsPath('output_caravan_US/attributes/10259000'), WindowsPath('output_caravan_US/attributes/10259200'), WindowsPath('output_caravan_US/attributes/10263500'), WindowsPath('output_caravan_US/attributes/10310500'), WindowsPath('output_caravan_US/attributes/10316500'), WindowsPath('output_caravan_US/attributes/10329500'), WindowsPath('output_caravan_US/attributes/10336645'), WindowsPath('output_caravan_US/attributes/10336660'), WindowsPath('output_caravan_US/attributes/10336740'), WindowsPath('output_caravan_US/attributes/10343500'), WindowsPath('output_caravan_US/attributes/10348850'), WindowsPath('output_caravan_US/attributes/10396000'), WindowsPath('output_caravan_US/attributes/11098000'), WindowsPath('output_caravan_US/attributes/11124500'), WindowsPath('output_caravan_US/attributes/11141280'), WindowsPath('output_caravan_US/attributes/11143000'), WindowsPath('output_caravan_US/attributes/11148900'), WindowsPath('output_caravan_US/attributes/11151300'), WindowsPath('output_caravan_US/attributes/11162500'), WindowsPath('output_caravan_US/attributes/11176400'), WindowsPath('output_caravan_US/attributes/11180500'), WindowsPath('output_caravan_US/attributes/11180960'), WindowsPath('output_caravan_US/attributes/11224500'), WindowsPath('output_caravan_US/attributes/11230500'), WindowsPath('output_caravan_US/attributes/11237500'), WindowsPath('output_caravan_US/attributes/11253310'), WindowsPath('output_caravan_US/attributes/11264500'), WindowsPath('output_caravan_US/attributes/11266500'), WindowsPath('output_caravan_US/attributes/11274500'), WindowsPath('output_caravan_US/attributes/11274630'), WindowsPath('output_caravan_US/attributes/11284400'), WindowsPath('output_caravan_US/attributes/11299600'), WindowsPath('output_caravan_US/attributes/11381500'), WindowsPath('output_caravan_US/attributes/11383500'), WindowsPath('output_caravan_US/attributes/11451100'), WindowsPath('output_caravan_US/attributes/11468500'), WindowsPath('output_caravan_US/attributes/11473900'), WindowsPath('output_caravan_US/attributes/11475560'), WindowsPath('output_caravan_US/attributes/11476600'), WindowsPath('output_caravan_US/attributes/11478500'), WindowsPath('output_caravan_US/attributes/11480390'), WindowsPath('output_caravan_US/attributes/11481200'), WindowsPath('output_caravan_US/attributes/11482500'), WindowsPath('output_caravan_US/attributes/11522500'), WindowsPath('output_caravan_US/attributes/11523200'), WindowsPath('output_caravan_US/attributes/11528700'), WindowsPath('output_caravan_US/attributes/11532500'), WindowsPath('output_caravan_US/attributes/12010000'), WindowsPath('output_caravan_US/attributes/12013500'), WindowsPath('output_caravan_US/attributes/12020000'), WindowsPath('output_caravan_US/attributes/12025000'), WindowsPath('output_caravan_US/attributes/12025700'), WindowsPath('output_caravan_US/attributes/12035000'), WindowsPath('output_caravan_US/attributes/12040500'), WindowsPath('output_caravan_US/attributes/12041200'), WindowsPath('output_caravan_US/attributes/12043000'), WindowsPath('output_caravan_US/attributes/12048000'), WindowsPath('output_caravan_US/attributes/12054000'), WindowsPath('output_caravan_US/attributes/12056500'), WindowsPath('output_caravan_US/attributes/12073500'), WindowsPath('output_caravan_US/attributes/12082500'), WindowsPath('output_caravan_US/attributes ...
# basinstest: ['6']
# names: ['6']
# dfs: [            p_mean  pet_mean_ERA5_LAND  pet_mean_FAO_PM  aridity_ERA5_LAND  \
# gauge_id
# 6         2.208724            3.663488         1.576936           1.658644
#
#           aridity_FAO_PM  frac_snow  moisture_index_ERA5_LAND  \
# gauge_id
# 6               0.713958          0                 -0.224735
#
#           seasonality_ERA5_LAND  moisture_index_FAO_PM  seasonality_FAO_PM  \
# gauge_id
# 6                      1.168391               0.307145            1.168536
#
#           ...  ria_ha_usu  riv_tc_usu  pop_ct_usu  dor_pc_pva  \
# gauge_id  ...
# 6         ...    1192.807     9015.12    2078.817           0
#
#           area_fraction_used_for_aggregation  gauge_lat  gauge_lon  \
# gauge_id
# 6                                          1  50.885418    3.68613
#
#                     gauge_name  country        area
# gauge_id
# 6         Nederzwalm/Zwalmbeek  Belgium  111.249644
#
# [1 rows x 215 columns]]
# dfprint: <bound method NDFrame.head of             p_mean  pet_mean_ERA5_LAND  pet_mean_FAO_PM  aridity_ERA5_LAND  \
# gauge_id
# 6         2.208724            3.663488         1.576936           1.658644
#
#           aridity_FAO_PM  frac_snow  moisture_index_ERA5_LAND  \
# gauge_id
# 6               0.713958          0                 -0.224735
#
#           seasonality_ERA5_LAND  moisture_index_FAO_PM  seasonality_FAO_PM  \
# gauge_id
# 6                      1.168391               0.307145            1.168536
#
#           ...  ria_ha_usu  riv_tc_usu  pop_ct_usu  dor_pc_pva  \
# gauge_id  ...
# 6         ...    1192.807     9015.12    2078.817           0
#
#           area_fraction_used_for_aggregation  gauge_lat  gauge_lon  \
# gauge_id
# 6                                          1  50.885418    3.68613
#
#                     gauge_name  country        area
# gauge_id
# 6         Nederzwalm/Zwalmbeek  Belgium  111.249644
#
# [1 rows x 215 columns]>
# dfindexen: Index(['6'], dtype='object')
# df      p_mean  pet_mean_ERA5_LAND  pet_mean_FAO_PM  aridity_ERA5_LAND  \
# 6  2.208724            3.663488         1.576936           1.658644
#
#    aridity_FAO_PM  frac_snow  moisture_index_ERA5_LAND  seasonality_ERA5_LAND  \
# 6        0.713958          0                 -0.224735               1.168391
#
#    moisture_index_FAO_PM  seasonality_FAO_PM  ...  ria_ha_usu  riv_tc_usu  \
# 6               0.307145            1.168536  ...    1192.807     9015.12
#
#    pop_ct_usu  dor_pc_pva  area_fraction_used_for_aggregation  gauge_lat  \
# 6    2078.817           0                                   1  50.885418
#
#    gauge_lon            gauge_name  country        area
# 6    3.68613  Nederzwalm/Zwalmbeek  Belgium  111.249644
#
# [1 rows x 215 columns]
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  1.99it/s]
# d:\Users\ddknop\Documents\envs\neuralhydrology\lib\site-packages\neuralhydrology\evaluation\tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Evaluation:   0%|          | 0/1 [00:00<?, ?it/s]basins?: None
# subdataset: None
# ...
# basinstest: ['6']
# names: ['6']
# dfs: [            p_mean  pet_mean_ERA5_LAND  pet_mean_FAO_PM  aridity_ERA5_LAND  \
# gauge_id
# 6         2.208724            3.663488         1.576936           1.658644
#
#           aridity_FAO_PM  frac_snow  moisture_index_ERA5_LAND  \
# gauge_id
# 6               0.713958          0                 -0.224735
#
#           seasonality_ERA5_LAND  moisture_index_FAO_PM  seasonality_FAO_PM  \
# gauge_id
# 6                      1.168391               0.307145            1.168536
#
#           ...  ria_ha_usu  riv_tc_usu  pop_ct_usu  dor_pc_pva  \
# gauge_id  ...
# 6         ...    1192.807     9015.12    2078.817           0
#
#           area_fraction_used_for_aggregation  gauge_lat  gauge_lon  \
# gauge_id
# 6                                          1  50.885418    3.68613
#
#                     gauge_name  country        area
# gauge_id
# 6         Nederzwalm/Zwalmbeek  Belgium  111.249644
#
# [1 rows x 215 columns]]
# dfprint: <bound method NDFrame.head of             p_mean  pet_mean_ERA5_LAND  pet_mean_FAO_PM  aridity_ERA5_LAND  \
# gauge_id
# 6         2.208724            3.663488         1.576936           1.658644
#
#           aridity_FAO_PM  frac_snow  moisture_index_ERA5_LAND  \
# gauge_id
# 6               0.713958          0                 -0.224735
#
#           seasonality_ERA5_LAND  moisture_index_FAO_PM  seasonality_FAO_PM  \
# gauge_id
# 6                      1.168391               0.307145            1.168536
#
#           ...  ria_ha_usu  riv_tc_usu  pop_ct_usu  dor_pc_pva  \
# gauge_id  ...
# 6         ...    1192.807     9015.12    2078.817           0
#
#           area_fraction_used_for_aggregation  gauge_lat  gauge_lon  \
# gauge_id
# 6                                          1  50.885418    3.68613
#
#                     gauge_name  country        area
# gauge_id
# 6         Nederzwalm/Zwalmbeek  Belgium  111.249644
#
# [1 rows x 215 columns]>
# dfindexen: Index(['6'], dtype='object')
# df      p_mean  pet_mean_ERA5_LAND  pet_mean_FAO_PM  aridity_ERA5_LAND  \
# 6  2.208724            3.663488         1.576936           1.658644
#
#    aridity_FAO_PM  frac_snow  moisture_index_ERA5_LAND  seasonality_ERA5_LAND  \
# 6        0.713958          0                 -0.224735               1.168391
#
#    moisture_index_FAO_PM  seasonality_FAO_PM  ...  ria_ha_usu  riv_tc_usu  \
# 6               0.307145            1.168536  ...    1192.807     9015.12
#
#    pop_ct_usu  dor_pc_pva  area_fraction_used_for_aggregation  gauge_lat  \
# 6    2078.817           0                                   1  50.885418
#
#    gauge_lon            gauge_name  country        area
# 6    3.68613  Nederzwalm/Zwalmbeek  Belgium  111.249644
#
# [1 rows x 215 columns]
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  1.86it/s]
# d:\Users\ddknop\Documents\envs\neuralhydrology\lib\site-packages\neuralhydrology\evaluation\tester.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Evaluation:   0%|          | 0/1 [00:00<?, ?it/s]basins?: None
# subdataset: None
# subdatasetdirs: [WindowsPath('output_caravan_US/attributes/10023000'), WindowsPath('output_caravan_US/attributes/10166430'), WindowsPath('output_caravan_US/attributes/10172700'), WindowsPath('output_caravan_US/attributes/10172800'), WindowsPath('output_caravan_US/attributes/10173450'), WindowsPath('output_caravan_US/attributes/10205030'), WindowsPath('output_caravan_US/attributes/10234500'), WindowsPath('output_caravan_US/attributes/10242000'), WindowsPath('output_caravan_US/attributes/10244950'), WindowsPath('output_caravan_US/attributes/10249300'), WindowsPath('output_caravan_US/attributes/10258000'), WindowsPath('output_caravan_US/attributes/10258500'), WindowsPath('output_caravan_US/attributes/10259000'), WindowsPath('output_caravan_US/attributes/10259200'), WindowsPath('output_caravan_US/attributes/10263500'), WindowsPath('output_caravan_US/attributes/10310500'), WindowsPath('output_caravan_US/attributes/10316500'), WindowsPath('output_caravan_US/attributes/10329500'), WindowsPath('output_caravan_US/attributes/10336645'), WindowsPath('output_caravan_US/attributes/10336660'), WindowsPath('output_caravan_US/attributes/10336740'), WindowsPath('output_caravan_US/attributes/10343500'), WindowsPath('output_caravan_US/attributes/10348850'), WindowsPath('output_caravan_US/attributes/10396000'), WindowsPath('output_caravan_US/attributes/11098000'), WindowsPath('output_caravan_US/attributes/11124500'), WindowsPath('output_caravan_US/attributes/11141280'), WindowsPath('output_caravan_US/attributes/11143000'), WindowsPath('output_caravan_US/attributes/11148900'), WindowsPath('output_caravan_US/attributes/11151300'), WindowsPath('output_caravan_US/attributes/11162500'), WindowsPath('output_caravan_US/attributes/11176400'), WindowsPath('output_caravan_US/attributes/11180500'), WindowsPath('output_caravan_US/attributes/11180960'), WindowsPath('output_caravan_US/attributes/11224500'), WindowsPath('output_caravan_US/attributes/11230500'), WindowsPath('output_caravan_US/attributes/11237500'), WindowsPath('output_caravan_US/attributes/11253310'), WindowsPath('output_caravan_US/attributes/11264500'), WindowsPath('output_caravan_US/attributes/11266500'), WindowsPath('output_caravan_US/attributes/11274500'), WindowsPath('output_caravan_US/attributes/11274630'), WindowsPath('output_caravan_US/attributes/11284400'), WindowsPath('output_caravan_US/attributes/11299600'), WindowsPath('output_caravan_US/attributes/11381500'), WindowsPath('output_caravan_US/attributes/11383500'), WindowsPath('output_caravan_US/attributes/11451100'), WindowsPath('output_caravan_US/attributes/11468500'), WindowsPath('output_caravan_US/attributes/11473900'), WindowsPath('output_caravan_US/attributes/11475560'), WindowsPath('output_caravan_US/attributes/11476600'), WindowsPath('output_caravan_US/attributes/11478500'), WindowsPath('output_caravan_US/attributes/11480390'), WindowsPath('output_caravan_US/attributes/11481200'), WindowsPath('output_caravan_US/attributes/11482500'), WindowsPath('output_caravan_US/attributes/11522500'), WindowsPath('output_caravan_US/attributes/11523200'), WindowsPath('output_caravan_US/attributes/11528700'), WindowsPath('output_caravan_US/attributes/11532500'), WindowsPath('output_caravan_US/attributes/12010000'), WindowsPath('output_caravan_US/attributes/12013500'), WindowsPath('output_caravan_US/attributes/12020000'), WindowsPath('output_caravan_US/attributes/12025000'), WindowsPath('output_caravan_US/attributes/12025700'), WindowsPath('output_caravan_US/attributes/12035000'), WindowsPath('output_caravan_US/attributes/12040500'), WindowsPath('output_caravan_US/attributes/12041200'), WindowsPath('output_caravan_US/attributes/12043000'), WindowsPath('output_caravan_US/attributes/12048000'), WindowsPath('output_caravan_US/attributes/12054000'), WindowsPath('output_caravan_US/attributes/12056500'), WindowsPath('output_caravan_US/attributes/12073500'), WindowsPath('output_caravan_US/attributes/12082500'), WindowsPath('output_caravan_US/attributes ...
# basinstest: ['6']
# names: ['6']
# dfs: [            p_mean  pet_mean_ERA5_LAND  pet_mean_FAO_PM  aridity_ERA5_LAND  \
# gauge_id
# 6         2.208724            3.663488         1.576936           1.658644
#
#           aridity_FAO_PM  frac_snow  moisture_index_ERA5_LAND  \
# gauge_id
# 6               0.713958          0                 -0.224735
#
#           seasonality_ERA5_LAND  moisture_index_FAO_PM  seasonality_FAO_PM  \
# gauge_id
# 6                      1.168391               0.307145            1.168536
#
#           ...  ria_ha_usu  riv_tc_usu  pop_ct_usu  dor_pc_pva  \
# gauge_id  ...
# 6         ...    1192.807     9015.12    2078.817           0
#
#           area_fraction_used_for_aggregation  gauge_lat  gauge_lon  \
# gauge_id
# 6                                          1  50.885418    3.68613
#
#                     gauge_name  country        area
# gauge_id
# 6         Nederzwalm/Zwalmbeek  Belgium  111.249644
#
# [1 rows x 215 columns]]
# dfprint: <bound method NDFrame.head of             p_mean  pet_mean_ERA5_LAND  pet_mean_FAO_PM  aridity_ERA5_LAND  \
# gauge_id
# 6         2.208724            3.663488         1.576936           1.658644
#
#           aridity_FAO_PM  frac_snow  moisture_index_ERA5_LAND  \
# gauge_id
# 6               0.713958          0                 -0.224735
#
#           seasonality_ERA5_LAND  moisture_index_FAO_PM  seasonality_FAO_PM  \
# gauge_id
# 6                      1.168391               0.307145            1.168536
#
#           ...  ria_ha_usu  riv_tc_usu  pop_ct_usu  dor_pc_pva  \
# gauge_id  ...
# 6         ...    1192.807     9015.12    2078.817           0
#
#           area_fraction_used_for_aggregation  gauge_lat  gauge_lon  \
# gauge_id
# 6                                          1  50.885418    3.68613
#
#                     gauge_name  country        area
# gauge_id
# 6         Nederzwalm/Zwalmbeek  Belgium  111.249644
#
# [1 rows x 215 columns]>
# dfindexen: Index(['6'], dtype='object')
# df      p_mean  pet_mean_ERA5_LAND  pet_mean_FAO_PM  aridity_ERA5_LAND  \
# 6  2.208724            3.663488         1.576936           1.658644
#
#    aridity_FAO_PM  frac_snow  moisture_index_ERA5_LAND  seasonality_ERA5_LAND  \
# 6        0.713958          0                 -0.224735               1.168391
#
#    moisture_index_FAO_PM  seasonality_FAO_PM  ...  ria_ha_usu  riv_tc_usu  \
# 6               0.307145            1.168536  ...    1192.807     9015.12
#
#    pop_ct_usu  dor_pc_pva  area_fraction_used_for_aggregation  gauge_lat  \
# 6    2078.817           0                                   1  50.885418
#
#    gauge_lon            gauge_name  country        area
# 6    3.68613  Nederzwalm/Zwalmbeek  Belgium  111.249644
#
# [1 rows x 215 columns]
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  1.94it/s]

# %%
# Initialize variables to track the best NSE and the corresponding epoch
max_nse = -float('inf')  # Set to negative infinity initially
best_epoch = None

# Loop through epochs 1 to 50
for i in range(1, 21):  # Epochs 1 to 50
    # Format the folder name for the current epoch
    epoch_folder = base_dir1 / f"model_epoch{i:03d}"
    metrics_file = epoch_folder / "test_metrics.csv"

    # Check if the test_metrics.csv file exists
    if not metrics_file.exists():
        print(f"test_metrics.csv file not found for epoch {i}. Skipping...")
        continue

    # Load the CSV file into a DataFrame
    df = pd.read_csv(metrics_file)

    # Extract the NSE value from the dataframe (assuming NSE is in a column named 'NSE')
    if 'NSE' in df.columns:
        nse_value = df['NSE'].iloc[0]  # Assuming NSE is on the first row
        print(f"Epoch {i}: NSE = {nse_value:.4f}")

        # Check if this is the highest NSE found so far
        if nse_value > max_nse:
            max_nse = nse_value
            best_epoch = i

# Output the best epoch and its NSE value
if best_epoch is not None:
    print(f"\nThe epoch with the highest NSE is Epoch {best_epoch} with an NSE value of {max_nse:.4f}")
else:
    print("No NSE values found.")

#%%
# fill in  with best epoch
with open(run_dir1 / "test" / "model_epoch008" / "test_results.p", "rb") as fp:
    results = pickle.load(fp)

qobs = results['6']['1D']['xr']['streamflow_obs']*area/(1000*3600*24)
qsim = results['6']['1D']['xr']['streamflow_sim']*area/(1000*3600*24)

fig, ax = plt.subplots(figsize=(16,10))
ax.plot(qobs['date'], qobs)
ax.plot(qsim['date'], qsim)
ax.set_ylabel("Discharge (m³/s)")
ax.set_title(f"Test period - NSE {results['6']['1D']['NSE']:.3f}")

    #data properties

values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))
for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# Epoch 1: NSE = 0.1659
# Epoch 2: NSE = 0.1919
# Epoch 3: NSE = 0.3337
# Epoch 4: NSE = 0.3662
# Epoch 5: NSE = 0.3862
# Epoch 6: NSE = 0.2748
# Epoch 7: NSE = 0.3533
# Epoch 8: NSE = 0.4036
# Epoch 9: NSE = 0.3788
# Epoch 10: NSE = 0.3838
# Epoch 11: NSE = 0.3526
# Epoch 12: NSE = 0.2384
# Epoch 13: NSE = 0.3478
# Epoch 14: NSE = 0.3279
# Epoch 15: NSE = 0.3942
# Epoch 16: NSE = 0.3507
# Epoch 17: NSE = 0.3497
# Epoch 18: NSE = 0.2001
# Epoch 19: NSE = 0.3319
# Epoch 20: NSE = 0.2866
#
# The epoch with the highest NSE is Epoch 8 with an NSE value of 0.4036
# d:\Users\ddknop\Documents\envs\neuralhydrology\lib\site-packages\neuralhydrology\datautils\utils.py:340: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# d:\Users\ddknop\Documents\envs\neuralhydrology\lib\site-packages\neuralhydrology\datautils\utils.py:383: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# NSE: 0.403
# MSE: 0.832
# RMSE: 0.912
# KGE: 0.599
# Alpha-NSE: 0.806
# Beta-KGE: 1.056
# Beta-NSE: 0.043
# Pearson-r: 0.654
# FHV: -29.317
# FMS: 5.508
# FLV: -366.026
# Peak-Timing: 1.909
# Peak-MAPE: 67.863

# %%
# Initialize variables to track the best NSE and the corresponding epoch
max_nse = -float('inf')  # Set to negative infinity initially
best_epoch = None

# Loop through epochs 1 to 50
for i in range(1, 21):  # Epochs 1 to 50
    # Format the folder name for the current epoch
    epoch_folder = base_dir2 / f"model_epoch{i:03d}"
    metrics_file = epoch_folder / "test_metrics.csv"

    # Check if the test_metrics.csv file exists
    if not metrics_file.exists():
        print(f"test_metrics.csv file not found for epoch {i}. Skipping...")
        continue

    # Load the CSV file into a DataFrame
    df = pd.read_csv(metrics_file)

    # Extract the NSE value from the dataframe (assuming NSE is in a column named 'NSE')
    if 'NSE' in df.columns:
        nse_value = df['NSE'].iloc[0]  # Assuming NSE is on the first row
        print(f"Epoch {i}: NSE = {nse_value:.4f}")

        # Check if this is the highest NSE found so far
        if nse_value > max_nse:
            max_nse = nse_value
            best_epoch = i

# Output the best epoch and its NSE value
if best_epoch is not None:
    print(f"\nThe epoch with the highest NSE is Epoch {best_epoch} with an NSE value of {max_nse:.4f}")
else:
    print("No NSE values found.")

#%%
# fill in  with best epoch
with open(run_dir2 / "test" / "model_epoch002" / "test_results.p", "rb") as fp:
    results = pickle.load(fp)

qobs = results['6']['1D']['xr']['streamflow_obs']*area/(1000*3600*24)
qsim = results['6']['1D']['xr']['streamflow_sim']*area/(1000*3600*24)

fig, ax = plt.subplots(figsize=(16,10))
ax.plot(qobs['date'], qobs)
ax.plot(qsim['date'], qsim)
ax.set_ylabel("Discharge (m³/s)")
ax.set_title(f"Test period - NSE {results['6']['1D']['NSE']:.3f}")

    #data properties

values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))
for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# Epoch 1: NSE = 0.3890
# Epoch 2: NSE = 0.3954
# Epoch 3: NSE = 0.2499
# Epoch 4: NSE = 0.2932
# Epoch 5: NSE = 0.3707
# Epoch 6: NSE = 0.1791
# Epoch 7: NSE = 0.2897
# Epoch 8: NSE = 0.1733
# Epoch 9: NSE = 0.3434
# Epoch 10: NSE = 0.1312
# Epoch 11: NSE = 0.1246
# Epoch 12: NSE = 0.2638
# Epoch 13: NSE = 0.3371
# Epoch 14: NSE = -0.0917
# Epoch 15: NSE = 0.1592
# Epoch 16: NSE = -0.0433
# Epoch 17: NSE = 0.2540
# Epoch 18: NSE = 0.1820
# Epoch 19: NSE = 0.2620
# Epoch 20: NSE = 0.1846
#
# The epoch with the highest NSE is Epoch 2 with an NSE value of 0.3954
# d:\Users\ddknop\Documents\envs\neuralhydrology\lib\site-packages\neuralhydrology\datautils\utils.py:340: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# d:\Users\ddknop\Documents\envs\neuralhydrology\lib\site-packages\neuralhydrology\datautils\utils.py:383: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# NSE: 0.395
# MSE: 0.842
# RMSE: 0.918
# KGE: 0.539
# Alpha-NSE: 0.760
# Beta-KGE: 1.186
# Beta-NSE: 0.142
# Pearson-r: 0.653
# FHV: -33.402
# FMS: -17.310
# FLV: -374.623
# Peak-Timing: 1.727
# Peak-MAPE: 67.180

# %%
# Initialize variables to track the best NSE and the corresponding epoch
max_nse = -float('inf')  # Set to negative infinity initially
best_epoch = None

# Loop through epochs 1 to 50
for i in range(1, 21):  # Epochs 1 to 50
    # Format the folder name for the current epoch
    epoch_folder = base_dir3 / f"model_epoch{i:03d}"
    metrics_file = epoch_folder / "test_metrics.csv"

    # Check if the test_metrics.csv file exists
    if not metrics_file.exists():
        print(f"test_metrics.csv file not found for epoch {i}. Skipping...")
        continue

    # Load the CSV file into a DataFrame
    df = pd.read_csv(metrics_file)

    # Extract the NSE value from the dataframe (assuming NSE is in a column named 'NSE')
    if 'NSE' in df.columns:
        nse_value = df['NSE'].iloc[0]  # Assuming NSE is on the first row
        print(f"Epoch {i}: NSE = {nse_value:.4f}")

        # Check if this is the highest NSE found so far
        if nse_value > max_nse:
            max_nse = nse_value
            best_epoch = i

# Output the best epoch and its NSE value
if best_epoch is not None:
    print(f"\nThe epoch with the highest NSE is Epoch {best_epoch} with an NSE value of {max_nse:.4f}")
else:
    print("No NSE values found.")

#%%
# fill in  with best epoch
with open(run_dir3 / "test" / "model_epoch001" / "test_results.p", "rb") as fp:
    results = pickle.load(fp)

qobs = results['6']['1D']['xr']['streamflow_obs']*area/(1000*3600*24)
qsim = results['6']['1D']['xr']['streamflow_sim']*area/(1000*3600*24)

fig, ax = plt.subplots(figsize=(16,10))
ax.plot(qobs['date'], qobs)
ax.plot(qsim['date'], qsim)
ax.set_ylabel("Discharge (m³/s)")
ax.set_title(f"Test period - NSE {results['6']['1D']['NSE']:.3f}")

    #data properties

values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))
for key, val in values.items():
    print(f"{key}: {val:.3f}")

# Zet qsim om naar DataFrame en exporteer naar CSV
qsim_df = qsim.to_dataframe(name='qmodm3s').reset_index()
qsim_df.to_csv("qsim_output.csv", index=False)
# Out:
# Epoch 1: NSE = 0.4267
# Epoch 2: NSE = 0.3547
# Epoch 3: NSE = 0.1983
# Epoch 4: NSE = 0.2825
# Epoch 5: NSE = 0.0896
# Epoch 6: NSE = 0.0645
# Epoch 7: NSE = 0.1779
# Epoch 8: NSE = 0.0891
# Epoch 9: NSE = 0.0888
# Epoch 10: NSE = 0.1586
# Epoch 11: NSE = 0.1137
# Epoch 12: NSE = 0.2095
# Epoch 13: NSE = 0.1995
# Epoch 14: NSE = 0.2353
# Epoch 15: NSE = 0.1233
# Epoch 16: NSE = 0.3144
# Epoch 17: NSE = 0.1747
# Epoch 18: NSE = 0.1182
# Epoch 19: NSE = 0.1936
# Epoch 20: NSE = 0.2015
#
# The epoch with the highest NSE is Epoch 1 with an NSE value of 0.4267
# d:\Users\ddknop\Documents\envs\neuralhydrology\lib\site-packages\neuralhydrology\datautils\utils.py:340: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# d:\Users\ddknop\Documents\envs\neuralhydrology\lib\site-packages\neuralhydrology\datautils\utils.py:383: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# NSE: 0.425
# MSE: 0.801
# RMSE: 0.895
# KGE: 0.465
# Alpha-NSE: 0.591
# Beta-KGE: 1.020
# Beta-NSE: 0.015
# Pearson-r: 0.655
# FHV: -49.256
# FMS: -30.425
# FLV: -312.353
# Peak-Timing: 1.909
# Peak-MAPE: 74.074

# %%
def FHV(Qmod, Qobs, exceedance_prob=0.02):
    """
    Calculate the percentage bias in percent bias in flow duration curve high-segment volume (FHV) as defined in Yilmaz et al. (2008)

    Parameters
    ----------
    Qmod: numpy.array
        modelled flows
    Qobs: numpy.array
        observed flows
    exceedance_prob: float, default = 0.02
        highest fraction of flows to take into account for calculation of the bias
    Returns
    --------
    fhv: float
        percentage bias in percent bias in flow duration curve high-segment volume

    """
    nan_bool = np.isnan(Qobs)
    Qmod_nonan = Qmod[~nan_bool]
    Qobs_nonan = Qobs[~nan_bool]
    Q_mod_sorted = np.sort(Qmod_nonan)
    Q_obs_sorted = np.sort(Qobs_nonan)

    CDF_obs_distribution = ECDF(Q_obs_sorted)
    CDF_obs = CDF_obs_distribution(Q_obs_sorted)
    CDF_mod_distribution = ECDF(Q_mod_sorted)
    CDF_mod = CDF_mod_distribution(Q_mod_sorted)

    Q_obs_H = Q_obs_sorted[CDF_obs > 1 - exceedance_prob]
    Q_mod_H = Q_mod_sorted[CDF_mod > 1 - exceedance_prob]
    if len(Q_obs_H) != len(Q_mod_H):
        # occurs when e.g. modesl produces a constant input
        if len(Q_obs_H) < len(Q_mod_H):
            len_obs = len(Q_obs_H)
            Q_mod_H = Q_mod_H[0:len_obs]
        else: 
            len_mod = len(Q_mod_H)
            Q_obs_H = Q_obs_H[0:len_mod]
    fhv = 100 * np.nansum(Q_mod_H - Q_obs_H) / np.nansum(Q_obs_H)
    return fhv

# %%
print(qobs)
print(qsim)
qsim_avg = qsim.mean(skipna = True)
qobs_avg = qobs.mean(skipna=True)
print(qsim_avg)
print(qobs_avg)
qsim_avg.values/qobs_avg.values
# Out:
# <xarray.DataArray 'streamflow_obs' (date: 1843, time_step: 1)>
# array([[2.17077704],
#        [1.61516148],
#        [2.248305  ],
#        ...,
#        [1.70561074],
#        [4.21234148],
#        [1.70561074]])
# Coordinates:
#   * date       (date) datetime64[ns] 2017-12-15 2017-12-16 ... 2022-12-31
#   * time_step  (time_step) int64 0
# <xarray.DataArray 'streamflow_sim' (date: 1843, time_step: 1)>
# array([[2.23716833],
#        [1.88148333],
#        [1.77999074],
#        ...,
#        [2.07169648],
#        [2.24887852],
#        [3.04145741]])
# Coordinates:
#   * date       (date) datetime64[ns] 2017-12-15 2017-12-16 ... 2022-12-31
#   * time_step  (time_step) int64 0
# <xarray.DataArray 'streamflow_sim' ()>
# array(0.91578234)
# <xarray.DataArray 'streamflow_obs' ()>
# array(0.90099976)
# 1.01640686604335

# %%
def NSE_LF(Qmod, Qobs):
    """
    Calculate the low-flow Nash-Sutcliffe Efficiency (NSE_LF) using inverse flows.
    This variant of NSE emphasizes performance during low-flow periods.

    Only calculates for timestamps where no NaN values are present in the observed flows.

    Parameters
    ----------
    Qmod: numpy.array
        Modelled flows
    Qobs: numpy.array
        Observed flows

    Returns
    -------
    nse_lf: float
        Low-flow Nash-Sutcliffe Efficiency

    """
    nan_bool = np.isnan(Qobs)
    Qmod_nonan = Qmod[~nan_bool]
    Qobs_nonan = Qobs[~nan_bool]

    # Avoid division by zero using epsilon (1/100th of mean observed flow)
    epsilon = np.mean(Qobs_nonan) / 100

    Qmod_inv = 1 / (Qmod_nonan + epsilon)
    Qobs_inv = 1 / (Qobs_nonan + epsilon)

    T = (Qobs_inv - Qmod_inv) ** 2
    N = (Qobs_inv - np.mean(Qobs_inv)) ** 2

    nse_lf = 1 - np.sum(T) / np.sum(N)
    return nse_lf

# %%
NSE_LF(qsim.values, qobs.values)
# Out:
# -174.30809814657272

# %%
from statsmodels.distributions.empirical_distribution import ECDF

fhv = FHV(qsim.values, qobs.values, exceedance_prob=0.02)
print(fhv)
# Out:
# -49.25625210692973

# %%
# Best epochs for each run directory
epochs = [8, 2, 1]

# Initialize an empty dictionary to hold the ensemble mean results
ensemble_mean = {}

# Loop through each run directory and corresponding epoch
for run_dir, epoch in zip([run_dir1, run_dir2, run_dir3], epochs):
    # Define the path to the results file for the specified epoch
    test_results_path = run_dir / "test" / f"model_epoch{epoch:03}" / "test_results.p"

    # Load the results from the pickle file
    with open(test_results_path, "rb") as fp:
        results = pickle.load(fp)

    # Extract observed and simulated streamflow data
    # Note: Adjust the basin id (here '6') and timestep ('1D') as needed
    qobs = results['6']['1D']['xr']['streamflow_obs'] * area / (1000 * 3600 * 24)
    qsim = results['6']['1D']['xr']['streamflow_sim'] * area / (1000 * 3600 * 24)

    # Store the simulations (this will be used to calculate the ensemble mean later)
    ensemble_mean[run_dir] = qsim

# Now calculate the ensemble mean across the different runs
# Assuming all simulations are aligned by basin and timestep
qsim_ensemble = np.mean(np.stack(list(ensemble_mean.values())), axis=0)

# To calculate NSE for the ensemble mean, first load the observed data (qobs)
# Assuming observed data is same for all runs, so you can just load it once from any of the runs
qobs = results['6']['1D']['xr']['streamflow_obs'] * area / (1000 * 3600 * 24)

# Define the NSE calculation function
def nse(simulated, observed):
    return 1 - np.sum((simulated - observed) ** 2) / np.sum((observed - np.mean(observed)) ** 2)

print(qsim_ensemble)
print(qobs)
# Calculate NSE for the ensemble mean
nse_ensemble = nse(qsim_ensemble, qobs)

print(f'Ensemble mean NSE: {nse_ensemble}')
# Out:
# [[2.70532204]
#  [2.3159908 ]
#  [2.21343765]
#  ...
#  [2.53761327]
#  [2.83068488]
#  [3.89401358]]
# <xarray.DataArray 'streamflow_obs' (date: 1843, time_step: 1)>
# array([[2.17077704],
#        [1.61516148],
#        [2.248305  ],
#        ...,
#        [1.70561074],
#        [4.21234148],
#        [1.70561074]])
# Coordinates:
#   * date       (date) datetime64[ns] 2017-12-15 2017-12-16 ... 2022-12-31
#   * time_step  (time_step) int64 0
# Ensemble mean NSE: <xarray.DataArray 'streamflow_obs' ()>
# array(0.43769807)

# %%
print(len(qsim))
print(len(qobs))
print(qobs)
# Out:
# 1843
# 1843
# <xarray.DataArray 'streamflow_obs' (date: 1843, time_step: 1)>
# array([[2.17077704],
#        [1.61516148],
#        [2.248305  ],
#        ...,
#        [1.70561074],
#        [4.21234148],
#        [1.70561074]])
# Coordinates:
#   * date       (date) datetime64[ns] 2017-12-15 2017-12-16 ... 2022-12-31
#   * time_step  (time_step) int64 0

# %%
plt.figure(figsize=(6.3, 3.5))

# Plot observed streamflow
plt.plot(qobs['date'], qobs, label='Observed Discharge', color='blue', linewidth=1)

# Plot simulated streamflow
plt.plot(qobs['date'], qsim, label='Simulated Discharge', color='red', linewidth = 1)

# Add axis labels and styling
plt.xlabel('Date', fontsize=12)
plt.ylabel('Discharge (m³/s)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.xticks(rotation=45)
plt.style.use('seaborn-v0_8-whitegrid')

# Add legend
plt.legend(frameon=True, edgecolor='black')
plt.savefig("exp1_usa_final_ensemblemean.png", dpi=1000, bbox_inches='tight') 
# Show plot
plt.show()

# %%
qobs_isna = np.isnan(qobs.values)
qobs_isna_def = qobs.values[~qobs_isna]
qobs_mean =qobs_isna_def.mean()
print(qobs_mean)


qsim_ensemble_mean =qsim_ensemble.mean()
print(qsim_ensemble_mean)

qsim_ensemble_mean/qobs_mean
# Out:
# 0.900999761661384
# 0.9769600879248298
# 1.0843067107180806

# %%
def FHV(Qmod, Qobs, exceedance_prob=0.02):
    """
    Calculate the percentage bias in percent bias in flow duration curve high-segment volume (FHV) as defined in Yilmaz et al. (2008)

    Parameters
    ----------
    Qmod: numpy.array
        modelled flows
    Qobs: numpy.array
        observed flows
    exceedance_prob: float, default = 0.02
        highest fraction of flows to take into account for calculation of the bias
    Returns
    --------
    fhv: float
        percentage bias in percent bias in flow duration curve high-segment volume

    """
    nan_bool = np.isnan(Qobs)
    Qmod_nonan = Qmod[~nan_bool]
    Qobs_nonan = Qobs[~nan_bool]
    Q_mod_sorted = np.sort(Qmod_nonan)
    Q_obs_sorted = np.sort(Qobs_nonan)

    CDF_obs_distribution = ECDF(Q_obs_sorted)
    CDF_obs = CDF_obs_distribution(Q_obs_sorted)
    CDF_mod_distribution = ECDF(Q_mod_sorted)
    CDF_mod = CDF_mod_distribution(Q_mod_sorted)

    Q_obs_H = Q_obs_sorted[CDF_obs > 1 - exceedance_prob]
    Q_mod_H = Q_mod_sorted[CDF_mod > 1 - exceedance_prob]
    if len(Q_obs_H) != len(Q_mod_H):
        # occurs when e.g. modesl produces a constant input
        if len(Q_obs_H) < len(Q_mod_H):
            len_obs = len(Q_obs_H)
            Q_mod_H = Q_mod_H[0:len_obs]
        else: 
            len_mod = len(Q_mod_H)
            Q_obs_H = Q_obs_H[0:len_mod]
    fhv = 100 * np.nansum(Q_mod_H - Q_obs_H) / np.nansum(Q_obs_H)
    return fhv

# %%
from statsmodels.distributions.empirical_distribution import ECDF
qobs_def = qobs.values
print(qsim_ensemble)

fhv = FHV(qsim_ensemble, qobs_def, exceedance_prob=0.02)
print(fhv)
# Out:
# [[2.70532204]
#  [2.3159908 ]
#  [2.21343765]
#  ...
#  [2.53761327]
#  [2.83068488]
#  [3.89401358]]
# -38.26432630370059

# %%
NSE_LF(qsim_ensemble, qobs_def)
# Out:
# -54.499913647616644
